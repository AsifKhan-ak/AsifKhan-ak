# %%
user_table=int(input("Enter the number for which you want to generate the table: "))
i=1
while i<=10:
    print(f" 99 x {i} = {i*user_table}")
    i+=1
# Out:
#  99 x 1 = 99
#  99 x 2 = 198
#  99 x 3 = 297
#  99 x 4 = 396
#  99 x 5 = 495
#  99 x 6 = 594
#  99 x 7 = 693
#  99 x 8 = 792
#  99 x 9 = 891
#  99 x 10 = 990

# %%
i=5
while i<=15:
    print(f"3 x {i} = {i * 3}")
    i+=1
# Out:
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# 3 x 11 = 33
# 3 x 12 = 36
# 3 x 13 = 39
# 3 x 14 = 42
# 3 x 15 = 45
