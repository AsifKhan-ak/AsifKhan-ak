# %%
user_name= 'asif'
user_pasword= '1234'
user_name = input("enter your username")
if user_name == 'asif':
    user_input_password = int(input("enter your password"))
    if user_pasword == '1234':
        print("login successful")
    else:
        print("login failed")
else:
    print("user not found")
# Out:
# login successful
